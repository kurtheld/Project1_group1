# %%
# Dependencies
import pandas as pd
import numpy as np
import gmaps
import requests
from config import gkey
from config import ow_key
import time
import pprint
import pyowm
from math import sin, cos, sqrt, atan2, radians
import matplotlib.pyplot as plt

# %%
owm = pyowm.OWM(ow_key)
mgr = owm.agro_manager()
from pyowm.utils.geo import Polygon as GeoPolygon
mgr = owm.agro_manager()
# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
wine_data = "winemag-data_first150k.csv"
wine_df = pd.read_csv(wine_data)
wine_df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
wine_df2=wine_df.drop(columns= ["Unnamed: 0","region_2"], axis=1)
wine_df2.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1             variety                   winery
# 0        Napa Valley  Cabernet Sauvignon                    Heitz
# 1               Toro       Tinta de Toro  Bodega Carmen Rodríguez
# 2     Knights Valley     Sauvignon Blanc                 Macauley
# 3  Willamette Valley          Pinot Noir                    Ponzi
# 4             Bandol  Provence red blend     Domaine de la Bégude

# %%
dropped_wine= wine_df2.dropna()
dropped_wine.count()
# Out:
# country        77284
# description    77284
# designation    77284
# points         77284
# price          77284
# province       77284
# region_1       77284
# variety        77284
# winery         77284
# dtype: int64

# %%
us_data=dropped_wine[dropped_wine["country"]=="US"]
us_data
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# 11          US  From 18-year-old vines, this supple well-balan...
# 12          US  A standout even in this terrific lineup of 201...
# 14          US  With its sophisticated mix of mineral, acid an...
# 15          US  First made in 2006, this succulent luscious Ch...
# 16          US  This blockbuster, powerhouse of a wine suggest...
# 19          US  This fresh and lively medium-bodied wine is be...
# 20          US  Heitz has made this stellar rosé from the rare...
# 23          US  The apogee of this ambitious winery's white wi...
# 24          US  San Jose-based producer Adam Comartin heads 1,...
# 26          US  Bergström has made a Shea designate since 2003...
# 27          US  Focused and dense, this intense wine captures ...
# 28          US  Cranberry, baked rhubarb, anise and crushed sl...
# 29          US  This standout Rocks District wine brings earth...
# 31          US  Steely and perfumed, this wine sees only 20% n...
# 34          US  The aromas entice with notes of wet stone, hon...
# 47          US  Blended with 9% Malbec, 9% Cabernet Franc and ...
# 55          US  A blend of Cabernet from Grand Ciel (31%), Cie...
# 57          US  While exuberantly fruity, almost tropical on t...
# 58          US  Cabernet makes up just over half of this blend...
# 65          US  Fresh boysenberries and a blueberry sorbet cha...
# 67          US  From the producer's monumental Atlas Peak vine...
# 68          US  Big, bold, dark and chewy, this builds upon su...
# 69          US  A juiciness of cherry and vanilla spark the op...
# 150787              Sonoma County                Pinot Noir
# 150788         Santa Maria Valley                Chardonnay
# 150790              Sonoma County  Bordeaux-style Red Blend
# 150792       Russian River Valley                Chardonnay
# 150794                Napa Valley                 Zinfandel
# 150796       Santa Barbara County  Bordeaux-style Red Blend
# 150803                Napa Valley                Pinot Noir
# 150807                Edna Valley                Chardonnay
# 150812                Napa Valley                 Zinfandel
# 150827           Dry Creek Valley        Cabernet Sauvignon
# 150831       Russian River Valley                Chardonnay
# 150836                 California                Chardonnay
# 150856                 California                Chardonnay
# 150861              Sonoma County                Chardonnay
# 150873              Amador County                 Zinfandel
# 150883                 California                 Zinfandel
# 150889          Santa Ynez Valley                Pinot Noir
# 150892                 California                    Merlot
# 150914            Anderson Valley            White Riesling
# 150915                North Coast               White Blend
# 150916                Napa Valley           Champagne Blend
#
#                                winery
# 0                               Heitz
# 2                            Macauley
# 3                               Ponzi
# 8                           Bergström
# 9                           Blue Farm
# 11             Patricia Green Cellars
# 12             Patricia Green Cellars
# 14                     Domaine Serene
# 15                          Bergström
# 16                               Hall
# 19                       Gary Farrell
# 20                              Heitz
# 23                   Center of Effort
# 24                           Comartin
# 26                          Bergström
# 27                              Ponzi
# 28                               Roar
# 29                             Saviah
# 31                           Zepaltas
# 34                               Buty
# 47                           Brandlin
# 55                            DeLille
# 57               Dr. Konstantin Frank
# 58                             Efeste
# 65                     Jason-Stephens
# 67      Michael Mondavi Family Estate
# 68                      Panther Creek
# 69               Provenance Vineyards
# 70                            Raymond
# 75                     Archery Summit
# ...                               ...
# 150751                         Meeker
# 150753     Alexander Valley Vineyards
# 150755                  Maison Basque
# 150757                        Renwood
# 150758                         Wagner
# 150762                       Beringer
# 150764                          Schug
# 150769                        Kenwood
# 150774                          Fritz
# 150787                     Iron Horse
# 150788                          Byron
# 150790             Dry Creek Vineyard
# 150792                          Fritz
# 150794                    Green & Red
# 150796                        Babcock
# 150803                  Flora Springs
# 150807                         Talley
# 150812                     Stonehedge
# 150827             Dry Creek Vineyard
# 150831                          Fritz
# 150836                       Callaway
# 150856                    Forest Glen
# 150861                   Clos du Bois
# 150873                      Montevina
# 150883                     Glen Ellen
# 150889                         Lafond
# 150892                       Callaway
# 150914                        Navarro
# 150915                       Beringer
# 150916                    Schramsberg
#
# [40061 rows x 9 columns]

# %%
target_area = (us_data["region_1"]+","+us_data["province"])

# %%
unique_variety =us_data["variety"]
#unique_variety
unique_regions =us_data["region_1"].unique()
#unique_regions

# %%
ratings = us_data["points"]

# %%
wv = pd.DataFrame({"Location": target_area,"Wine Variety": unique_variety})
wv = pd.DataFrame({"Location": target_area,"Wine Ratings": ratings})
wv_group = wv.groupby("Location")
num_varieties = pd.DataFrame(wv_group["Wine Ratings"].mean()).reset_index()
#just sampling for testing purposes
sample_num_varieties = num_varieties.sample(200)
sample_num_varieties
num_varieties.count()
# Out:
# Location        250
# Wine Ratings    250
# dtype: int64

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
# Loop through the locations and run a lat/long search for each city
for idx, row in sample_num_varieties.iterrows():
#    print(idx)
    sample_target = row["Location"]
    # update address key value
    params['address'] = f"{sample_target}"
    # make request
    location_lat_lng = requests.get(base_url, params=params)
    # convert to json
    location_lat_lng = location_lat_lng.json()
    lat_long_geo = location_lat_lng["results"][0]["geometry"]
    try:
        latitude = lat_long_geo["location"]["lat"]
        longitude = lat_long_geo["location"]["lng"]
        
        
        north = latitude  + 0.01
        south = latitude  - 0.01
        east =  longitude + 0.01
        west =  longitude - 0.01
        
        try:
            gp = GeoPolygon([[
                [east, north],
                [west, north],
                [west, south],
               [east, south],
                [east, north]]])
            polygon = mgr.create_polygon(gp, 'my new shiny polygon')
            try:
                soil = mgr.soil_data(polygon) 
                sample_num_varieties.loc[idx, "Lat"] = latitude
                sample_num_varieties.loc[idx, "Lng"] = longitude  
                sample_num_varieties.loc[idx, "Soil Temperature (C) at 10 cm depth"] = soil.ten_cm_temp(unit='celsius') 
                sample_num_varieties.loc[idx, "Soil Moisture"] = soil.moisture
            except(AssertionError):
                continue
        except( pyowm.exceptions.OWMError ):
            continue
    except(KeyError, IndexError):
        print("Missing field/result... skipping.")
        continue
    time.sleep(3)
# Visualize to confirm lat lng appear
sample_num_varieties = sample_num_varieties.dropna()

# %%
sample_num_varieties
# Out:
#                                               Location  Wine Ratings  \
# 94                             Malibu Coast,California     92.000000
# 40                               Cole Ranch,California     85.888889
# 25                                 Carneros,California     88.767857
# 38                           Clements Hills,California     86.708333
# 160                           Placer County,California     86.833333
# 37                               Clear Lake,California     85.268293
# 190                       Santa Cruz County,California     89.400000
# 26                     Carneros-Napa Valley,California     90.166667
# 34                            Chiles Valley,California     87.083333
# 235                                  Virginia,Virginia     85.104545
# 217                             Southern Oregon,Oregon     87.245283
# 88                         Lime Kiln Valley,California     87.000000
# 202                           Sonoma County,California     87.406547
# 220                         Sta. Rita Hills,California     90.309412
# 145                              North Yuba,California     84.250000
# 243                           Yakima Valley,Washington     89.186548
# 167                            Red Mountain,Washington     90.594747
# 237                     Walla Walla Valley (OR),Oregon     93.312500
# 198                        Sierra Foothills,California     87.615385
# 107                                Middleburg,Virginia     87.000000
# 204  Sonoma County-Monterey County-Santa Barbara Co...     87.500000
# 233                                    Vermont,Vermont     84.500000
# 85                                  Lake Erie,New York     88.000000
# 96                             Marin County,California     89.684211
# 102                               Mendocino,California     87.656028
# 148                                Oakville,California     90.606618
# 136                    Napa-Sonoma-Monterey,California     87.000000
# 170                                Rockpile,California     88.490909
# 49                         Cucamonga Valley,California     86.272727
# 106                                  Michigan,Michigan     85.000000
# ..                                                 ...           ...
# 230                          Trinity County,California     82.875000
# 205               Sonoma County-Napa County,California     87.166667
# 133                             Napa-Sonoma,California     89.105263
# 210                                  Sonoma,California     83.000000
# 206        Sonoma County-San Joaquin County,California     91.000000
# 171                                Rogue Valley,Oregon     86.000000
# 178                        San Diego County,California     85.000000
# 60                                Fair Play,California     87.307692
# 226                                Temecula,California     84.093750
# 182                  San Luis Obispo County,California     87.539326
# 56                                El Dorado,California     86.497537
# 240          Western Connecticut Highlands,Connecticut     83.500000
# 128                                    Napa,California     90.689655
# 247  35.541432 -120.814814                                 10.07
# 231  43.211355 -123.346493                                  5.99
# 232  34.370488 -119.139064                                 10.09
# 195  42.691850  -76.920192                                  1.45
# 169  45.354283 -123.073993                                  8.11
#
#       Soil Moisture
# 94            0.469
# 40            0.221
# 25            0.242
# 38            0.136
# 160           0.282
# 37            0.230
# 190           0.331
# 26            0.215
# 34            0.207
# 235           0.182
# 217           0.236
# 88            0.205
# 202           0.347
# 220           0.173
# 145           0.209
# 243           0.151
# 167           0.235
# 237           0.274
# 198           0.192
# 107           0.166
# 204           0.347
# 233           0.314
# 85            0.326
# 96            0.234
# 102           0.343
# 148           0.209
# 136           0.366
# 170           0.126
# 49            0.087
# 106           0.152
# ..              ...
# 230           0.206
# 205           0.226
# 133           0.234
# 210           0.234
# 206           0.201
# 171           0.193
# 178           0.349
# 60            0.199
# 226           0.089
# 182           0.200
# 56            0.219
# 240           0.107
# 128           0.215
# 67            0.216
# 1             0.158
# 165           0.154
# 115           0.294
# 216           0.106
# 82            0.200
# 215           0.264
# 150           0.145
# 153           0.348
# 191           0.173
# 48            0.215
# 47            0.203
# 247           0.210
# 231           0.193
# 232           0.114
# 195           0.214
# 169           0.152
#
# [200 rows x 6 columns]

# %%
sample_num_varieties.to_csv("Wine_Soil.csv")

# %%
post_process = pd.read_csv("Wine_Soil.csv")

# %%
pnas_df = pd.read_csv("PNAS_Data/PNAS.csv")
pnas_df.head(100)
# Out:
#     latitude  longitude  spp_richness  N_dep_kghayr  precip_mm  temp_C_ave  \
# 0       46.1      -83.7            15          5.52     805.57        5.61
# 1       46.1      -83.7            11          5.52     805.57        5.61
# 2       46.1      -83.7            12          5.52     805.57        5.61
# 3       46.1      -83.7            17          5.52     805.57        5.61
# 4       46.1      -83.7            16          5.52     805.57        5.61
# 5       46.1      -83.7            12          5.52     805.57        5.61
# 6       45.7      -86.6            25          5.72     732.15        5.98
# 7       45.3      -83.6            19          8.89     751.28        6.67
# 8       46.0      -83.7            15          8.63     782.47        5.69
# 9       46.1      -84.9            17          7.94     822.37        5.05
# 10      46.0      -83.7            15          8.63     792.48        5.65
# 11      45.9      -87.2            27          7.30     755.55        5.72
# 12      46.1      -85.6            19          5.70     811.79        5.48
# 13      46.0      -83.8            25          5.53     768.74        5.68
# 14      44.1      -76.0            19         10.03     950.36        7.50
# 15      44.1      -76.0            25         10.03     950.36        7.50
# 16      44.1      -76.0            27         10.03     950.36        7.50
# 17      44.1      -76.1            14         10.39     971.36        7.44
# 18      44.1      -76.1            29         10.39     971.36        7.44
# 19      44.1      -76.1            20         10.39     971.36        7.44
# 20      44.1      -76.1            36         10.39     972.36        7.42
# 21      44.1      -76.1            34         10.39     972.36        7.42
# 22      44.1      -76.1             9         10.37     968.91        7.53
# 23      44.1      -76.1            20         10.37     968.91        7.53
# 24      44.1      -76.1            26         10.37     968.91        7.53
# 25      44.1      -76.1            20         10.37     968.91        7.53
# 26      44.1      -76.1            14         10.37     968.91        7.53
# 27      44.1      -76.1            13         10.37     968.91        7.53
# 28      44.1      -76.1            17         10.37     968.91        7.53
# 26  6.7            15.01            18.01      16.35      -5.98
# 27  6.7            15.01            18.01      16.35      -5.98
# 28  6.7            15.01            18.01      16.35      -5.98
# 29  6.7            15.01            18.01      16.35      -5.98
# ..  ...              ...              ...        ...        ...
# 70  4.8            11.60            12.95      12.22      -0.40
# 71  3.2             7.88             9.50       8.75       1.75
# 72  3.2             7.88             9.50       8.75       1.75
# 73  5.1            12.17            13.71      12.87      -1.53
# 74  5.1            12.17            13.71      12.87      -1.61
# 75  5.1            12.17            13.71      12.87      -1.03
# 76  4.8             7.18             8.81       7.99       0.27
# 77  5.1            12.17            13.71      12.87      -2.72
# 78  5.5             8.07             9.44       8.75       1.69
# 79  5.5            12.90            14.77      13.74      -3.32
# 80  4.5            10.99            12.22      11.57      -1.58
# 81  5.4            12.72            14.51      13.52      -1.82
# 82  4.5            10.99            12.22      11.57      -0.82
# 83  5.4             8.07             9.49       8.78       3.05
# 84  4.5            10.99            12.22      11.57      -0.82
# 85  5.0             7.44             8.68       8.05       1.98
# 86  5.0             7.44             8.68       8.05       1.98
# 87  3.2             7.88             9.50       8.75       1.75
# 88  3.2             7.88             9.50       8.75       1.75
# 89  5.1            12.17            13.71      12.87      -1.06
# 90  4.8            11.60            12.95      12.22      -1.78
# 91  5.5            12.90            14.77      13.74      -3.30
# 92  5.4            12.72            14.51      13.52      -1.82
# 93  4.5            10.99            12.22      11.57      -0.82
# 94  5.4             8.07             9.49       8.78       3.05
# 95  3.2             7.88             9.50       8.75       2.07
# 96  4.9            11.79            13.20      12.44      -0.97
# 97  5.5            12.90            14.77      13.74      -2.24
# 98  5.5            12.90            14.77      13.74      -2.30
# 99  5.9            13.62            15.83      14.61      -3.18
#
#     two_class_veg NVC_1_name                        NVC_2_name  \
# 0   closed_canopy     Forest                  Deciduous forest
# 1   closed_canopy     Forest                  Deciduous forest
# 2   closed_canopy     Forest                  Deciduous forest
# 3   closed_canopy     Forest                  Deciduous forest
# 4   closed_canopy     Forest                  Deciduous forest
# 5   closed_canopy     Forest                  Deciduous forest
# 6     open_canopy  Shrubland               Evergreen shrubland
# 7     open_canopy  Shrubland               Evergreen shrubland
# 8   closed_canopy     Forest                  Deciduous forest
# 9   closed_canopy     Forest                  Evergreen forest
# 10  closed_canopy     Forest                  Deciduous forest
# 11  closed_canopy     Forest                  Deciduous forest
# 12  closed_canopy     Forest                  Evergreen forest
# 13  closed_canopy     Forest                  Deciduous forest
# 14  closed_canopy     Forest                  Deciduous forest
# 15  closed_canopy     Forest                  Deciduous forest
# 16  closed_canopy     Forest                  Deciduous forest
# 17  closed_canopy     Forest                  Deciduous forest
# 18  closed_canopy     Forest                  Deciduous forest
# 19  closed_canopy     Forest                  Deciduous forest
# 20  closed_canopy     Forest                  Deciduous forest
# 21  closed_canopy     Forest                  Deciduous forest
# 22  closed_canopy     Forest                  Deciduous forest
# 23  closed_canopy     Forest                  Deciduous forest
# 24  closed_canopy     Forest                  Deciduous forest
# 25  closed_canopy     Forest                  Deciduous forest
# 26  closed_canopy     Forest                  Deciduous forest
# 27  closed_canopy     Forest                  Deciduous forest
# 28  closed_canopy     Forest                  Deciduous forest
# 29  closed_canopy     Forest                  Deciduous forest
# ..            ...        ...                               ...
# 70  closed_canopy     Forest  Mixed evergreen-deciduous forest
# 71  closed_canopy     Forest                  Evergreen forest
# 72  closed_canopy     Forest                  Evergreen forest
# 73  closed_canopy     Forest                  Evergreen forest
# 74  closed_canopy     Forest                  Evergreen forest
# 75  closed_canopy     Forest  Mixed evergreen-deciduous forest
# 76    open_canopy   Woodland                Evergreen woodland
# 77  closed_canopy     Forest                  Evergreen forest
# 78    open_canopy   Woodland                Evergreen woodland
# 79  closed_canopy     Forest                  Evergreen forest
# 80  closed_canopy     Forest                  Evergreen forest
# 81  closed_canopy     Forest                  Evergreen forest
# 82  closed_canopy     Forest                  Evergreen forest
# 83    open_canopy   Woodland                Evergreen woodland
# 84  closed_canopy     Forest                  Evergreen forest
# 85    open_canopy   Woodland                Evergreen woodland
# 86    open_canopy   Woodland                Evergreen woodland
# 87  closed_canopy     Forest                  Evergreen forest
# 88  closed_canopy     Forest                  Evergreen forest
# 89  closed_canopy     Forest                  Evergreen forest
# 90  closed_canopy     Forest                  Evergreen forest
# 91  closed_canopy     Forest                  Evergreen forest
# 92  closed_canopy     Forest                  Evergreen forest
# 93  closed_canopy     Forest                  Evergreen forest
# 94    open_canopy   Woodland                Evergreen woodland
# 95  closed_canopy     Forest                  Evergreen forest
# 96  closed_canopy     Forest                  Deciduous forest
# 97  closed_canopy     Forest                  Deciduous forest
# 98  closed_canopy     Forest                  Deciduous forest
# 99  closed_canopy     Forest                  Deciduous forest
#
#                                          NVC_Alliance proj_orig
# 0   Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 1   Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 2   Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 3   Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 4   Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 5   Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 6               Juniperus communis Shrubland Alliance     Alvar
# 7               Juniperus communis Shrubland Alliance     Alvar
# 8   Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 9                       Pinus strobus Forest Alliance     Alvar
# 10  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 11  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 12                      Pinus strobus Forest Alliance     Alvar
# 13  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 14  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 15  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 16  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 17  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 18  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 19  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 20  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 21  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 22  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 23  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 24  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 25  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 26  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 27  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 28  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# 29  Acer saccharum - Betula alleghaniensis - (Fagu...     Alvar
# ..                                                ...       ...
# 70  Quercus spp. - Pinus (rigida, echinata) Forest...       CVS
# 71                        Pinus taeda Forest Alliance       CVS
# 72                        Pinus taeda Forest Alliance       CVS
# 73                        Pinus taeda Forest Alliance       CVS
# 74                        Pinus taeda Forest Alliance       CVS
# 75  Quercus spp. - Pinus (rigida, echinata) Forest...       CVS
# 76                  Pinus palustris Woodland Alliance       CVS
# 77                        Pinus taeda Forest Alliance       CVS
# 78                  Pinus palustris Woodland Alliance       CVS
# 79                        Pinus taeda Forest Alliance       CVS
# 80                        Pinus taeda Forest Alliance       CVS
# 81                        Pinus taeda Forest Alliance       CVS
# 82                        Pinus taeda Forest Alliance       CVS
# 83   Pinus palustris / Quercus spp. Woodland Alliance       CVS
# 84                        Pinus taeda Forest Alliance       CVS
# 85                  Pinus palustris Woodland Alliance       CVS
# 86                  Pinus palustris Woodland Alliance       CVS
# 87                        Pinus taeda Forest Alliance       CVS
# 88                        Pinus taeda Forest Alliance       CVS
# 89                        Pinus taeda Forest Alliance       CVS
# 90                        Pinus taeda Forest Alliance       CVS
# 91                        Pinus taeda Forest Alliance       CVS
# 92                        Pinus taeda Forest Alliance       CVS
# 93                        Pinus taeda Forest Alliance       CVS
# 94   Pinus palustris / Quercus spp. Woodland Alliance       CVS
# 95                        Pinus taeda Forest Alliance       CVS
# 96  Quercus alba - (Quercus rubra, Carya spp.) For...       CVS
# 97  Quercus alba - (Quercus rubra, Carya spp.) For...       CVS
# 98  Quercus alba - (Quercus rubra, Carya spp.) For...       CVS
# 99  Quercus alba - (Quercus rubra, Carya spp.) For...       CVS
#
# [100 rows x 16 columns]

# %%
pnas_group = pnas_df.groupby(["latitude","longitude"]).mean()
pnas_group = pnas_group.reset_index()

# %%
pnas_reduced = pnas_group[["latitude","longitude","precip_mm","temp_C_ave","pH"]]
pnas_reduced.head(100)
# Out:
#     latitude  longitude    precip_mm  temp_C_ave        pH
# 0       27.3      -82.3  1470.280000   22.780000  4.600000
# 1       27.6      -81.3  1268.560000   22.500000  5.000000
# 2       27.6      -81.1  1307.155000   22.625000  4.450000
# 3       27.7      -81.3  1304.297500   22.392500  4.475000
# 4       27.7      -81.2  1324.100000   22.470000  4.300000
# 5       28.0      -81.1  1289.910000   22.280000  5.000000
# 6       28.1      -81.4  1210.510000   22.440000  4.500000
# 7       28.2      -82.6  1326.850000   22.050000  4.600000
# 8       28.3      -82.6  1328.430000   22.100000  4.700000
# 9       28.7      -82.4  1326.970000   21.590000  5.050000
# 10      28.7      -81.5  1280.070000   21.880000  4.300000
# 11      28.8      -82.4  1327.200000   21.535000  5.000000
# 12      29.0      -82.3  1309.360000   21.310000  4.800000
# 13      29.1      -82.6  1369.473333   20.980000  4.033333
# 14      29.1      -82.3  1304.900000   21.340000  4.700000
# 15      29.2      -81.9  1295.620000   21.330000  4.633333
# 16      29.2      -81.4  1341.443333   21.633333  4.733333
# 17      29.2      -81.2  1315.615000   21.605000  4.150000
# 18      29.3      -82.6  1411.450000   20.650000  4.500000
# 19      29.4      -82.6  1398.660000   20.720000  4.966667
# 20      29.5      -83.0  1454.080000   20.363333  4.966667
# 21      29.5      -82.6  1339.100000   20.620000  4.650000
# 22      29.5      -81.8  1328.177500   21.142500  4.725000
# 23      29.7      -85.3  1495.342500   20.165000  4.425000
# 24      29.7      -82.7  1319.465000   20.475000  5.650000
# 25      29.7      -82.5  1296.290000   20.650000  5.000000
# 26      29.7      -82.4  1292.850000   20.630000  5.600000
# 27      29.7      -82.0  1305.540000   20.870000  4.650000
# 28      29.7      -81.3  1321.510000   20.990000  5.900000
# 29      29.8      -82.7  1318.200000   20.500000  4.800000
# ..       ...        ...          ...         ...       ...
# 70      30.8      -85.0  1393.030000   19.710000  4.750000
# 71      30.8      -84.1  1330.640000   19.663333  4.666667
# 72      30.8      -84.0  1316.005000   19.635000  5.200000
# 73      30.8      -81.9  1275.820000   19.815000  4.500000
# 74      30.9      -86.7  1600.005000   19.160000  4.850000
# 75      30.9      -86.6  1599.690000   19.130000  4.800000
# 76      31.3      -84.5  1308.082500   19.201250  5.275000
# 77      31.7      -82.9  1192.690000   18.850000  5.500000
# 78      31.7      -82.8  1191.646667   18.846667  5.333333
# 79      31.8      -83.9  1207.430000   18.850000  4.600000
# 80      31.9      -82.1  1167.116667   19.263333  5.066667
# 81      31.9      -81.9  1160.340000   19.120000  5.300000
# 82      31.9      -81.8  1188.766667   19.253333  5.200000
# 83      32.0      -81.8  1173.177500   19.165000  5.000000
# 84      32.1      -82.8  1153.830000   18.530000  5.300000
# 85      32.1      -81.8  1162.090000   19.063333  5.266667
# 86      32.1      -81.5  1227.590000   19.125000  5.300000
# 87      32.2      -81.1  1242.570000   19.150000  5.300000
# 88      32.2      -80.9  1282.676000   19.220000  5.020000
# 89      32.2      -80.8  1304.576667   19.190000  6.433333
# 90      32.3      -84.9  1224.470000   18.060000  5.000000
# 91      32.3      -84.7  1250.160000   17.900000  5.300000
# 92      32.3      -80.8  1280.556667   19.218333  5.366667
# 93      32.4      -84.8  1225.187500   18.050000  5.225000
# 94      32.4      -84.7  1236.024000   17.888000  5.240000
# 95      32.5      -81.2  1225.850000   18.860000  5.500000
# 96      32.5      -81.1  1223.550000   18.840000  4.800000
# 97      32.5      -80.5  1232.130000   19.137500  6.300000
# 98      32.5      -80.4  1232.322857   19.118571  6.442857
# 99      32.6      -84.3  1207.460000   17.510000  5.300000
#
# [100 rows x 5 columns]

# %%
pnas_dat_lat = pnas_reduced["latitude"]
pnas_dat_lng = pnas_reduced["longitude"]


radians(pnas_dat_lat[0])
# Out:
# 0.47647488579445196

# %%
dist=[]
R =6373
for idx, row in post_process.iterrows():
    wine_lat = radians(row["Lat"])
    wine_lng = radians(row["Lng"])
    
    for i in range(len(pnas_dat_lat)):
            dlon = radians(pnas_dat_lng[i]) - wine_lng
            dlat = radians(pnas_dat_lat[i]) - wine_lat

            a = (sin(dlat/2))**2 + cos(wine_lat) * cos(radians(pnas_dat_lat[i])) * (sin(dlon/2))**2 
            c = 2 * atan2( sqrt(a), sqrt(1-a) ) 
            distance = R * c 
            dist.append(distance)
            
    ind = np.argmin(dist)
    post_process.loc[idx, "Precipitation(mm)"] = pnas_reduced.iloc[ind,2]
    post_process.loc[idx, "Avg. Air Temp (C)"] = pnas_reduced.iloc[ind,3]
    post_process.loc[idx, "pH(Soil)"] = pnas_reduced.iloc[ind,4]
    dist=[]

# %%
post_process.columns
# Out:
# Index(['Unnamed: 0', 'Location', 'Wine Ratings', 'Lat', 'Lng',
#        ' Soil Temperature (C) at 10 cm depth', ' Soil Moisture',
#        'Precipitation(mm)', 'Avg. Air Temp (C)', 'pH(Soil)'],
#       dtype='object')

# %%
plt.rcParams["font.family"] = "Arial"
plt.rcParams['font.size'] = 12
x1 = post_process["Avg. Air Temp (C)"]
y1 = post_process["Wine Ratings"]
plt.scatter(x1, y1, marker="o", facecolors="orange", edgecolors="black")
plt.title("Wine Ratings Vs. Air Temperature (Annual Average) in USA")
plt.xlabel("Annual Average Air Temperature (Celsius)")
plt.ylabel("Wine Ratings", fontname="Arial", fontsize=12)
plt.grid(linestyle='dotted')
plt.savefig("Ratings_Air_Temp.png",dpi=200)

# %%
x1 = post_process["Precipitation(mm)"]
y1 = post_process["Wine Ratings"]
plt.scatter(x1, y1, marker="o", facecolors="lightblue", edgecolors="black")
plt.title("Wine Ratings Vs. Precipitation (Annual Average) in USA")
plt.xlabel("Annual Average Precipitation (mm)")
plt.ylabel("Wine Ratings")
plt.grid(linestyle='dotted')
plt.savefig("Ratings_Precip.png",dpi=200)

# %%
x1 = post_process["pH(Soil)"]
y1 = post_process["Wine Ratings"]
plt.scatter(x1, y1, marker="o", facecolors="lightgreen", edgecolors="black")
plt.title("Wine Ratings Vs. pH(Soil) (Annual Average) in USA")
plt.xlabel("Annual Average pH of Soil")
plt.ylabel("Wine Ratings")
plt.grid(linestyle='dotted')
plt.savefig("Ratings_Soil_pH.png",dpi=200)

# %%
x1 = post_process[" Soil Moisture"]
y1 = post_process["Wine Ratings"]
plt.scatter(x1, y1, marker="o", facecolors="lightcoral", edgecolors="black")
plt.title("Wine Ratings Vs. Soil Moisture in USA")
plt.xlabel("Soil Moisture (Volume Fraction) at 10 cm depth")
plt.ylabel("Wine Ratings")
plt.grid(linestyle='dotted')
plt.savefig("Ratings_Soil_Moisture.png",dpi=200)

# %%
x1 = post_process[" Soil Temperature (C) at 10 cm depth"]
y1 = post_process["Wine Ratings"]
plt.scatter(x1, y1, marker="o", facecolors="pink", edgecolors="black")
plt.title("Wine Ratings Vs. Soil Temperature in USA")
plt.xlabel("Soil Temperature at 10 cm depth")
plt.ylabel("Wine Ratings")
plt.grid(linestyle='dotted')
plt.savefig("Ratings_Soil_Temp.png",dpi=200)

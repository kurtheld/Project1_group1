# %%
# Dependencies
import pandas as pd
import numpy as np
import gmaps
import requests
from config import  gkey
import time
# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
wine_data = "winemag-data_first150k.csv"
wine_df = pd.read_csv(wine_data)
wine_df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
wine_df2=wine_df.drop(columns= ["Unnamed: 0","region_2"], axis=1)
wine_df2.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1             variety                   winery
# 0        Napa Valley  Cabernet Sauvignon                    Heitz
# 1               Toro       Tinta de Toro  Bodega Carmen Rodríguez
# 2     Knights Valley     Sauvignon Blanc                 Macauley
# 3  Willamette Valley          Pinot Noir                    Ponzi
# 4             Bandol  Provence red blend     Domaine de la Bégude

# %%
dropped_wine= wine_df2.dropna()
dropped_wine.count()
# Out:
# country        77284
# description    77284
# designation    77284
# points         77284
# price          77284
# province       77284
# region_1       77284
# variety        77284
# winery         77284
# dtype: int64

# %%
target_area = (dropped_wine["region_1"]+","+dropped_wine["province"]+","+dropped_wine["country"])
type(target_area)
# Out:
# pandas.core.series.Series

# %%
unique_variety = dropped_wine["variety"]
type(unique_variety)
# Out:
# pandas.core.series.Series

# %%
wv = pd.DataFrame({"Location": target_area,"Wine Variety": unique_variety})
wv_group = wv.groupby("Location")
num_varieties = pd.DataFrame(wv_group["Wine Variety"].nunique()).reset_index()
#just sampling for testing purposes
sample_num_varieties = num_varieties.sample(1000)
sample_num_varieties
# Out:
#                                                Location  Wine Variety
# 857                               Sebino,Lombardy,Italy             1
# 740                          Quincy,Loire Valley,France             1
# 640                           Napa-Sonoma,California,US             7
# 189                 Châteaumeillant,Loire Valley,France             3
# 338                              Dundee Hills,Oregon,US             8
# 98                       Bordeaux Blanc,Bordeaux,France             7
# 1074                    Yadkin Valley,North Carolina,US             3
# 63                Barbera del Monferrato,Piedmont,Italy             1
# 646                             Neuquén,Other,Argentina            10
# 1008    Vin de Pays de Caux,Languedoc-Roussillon,France             1
# 698                       Petit Chablis,Burgundy,France             1
# 683                        Paestum,Southern Italy,Italy             1
# 275                   Coteaux de Verdon,Provence,France             1
# 453              La Consulta,Mendoza Province,Argentina             3
# 203                 Clarendon,South Australia,Australia             5
# 880                         Sonoma Valley,California,US            38
# 1052   Vino de la Tierra de Zamora,Northern Spain,Spain             1
# 915               Terra degli Osci,Southern Italy,Italy             4
# 465                               Lake Erie,New York,US             1
# 76                         Beaujolais,Beaujolais,France             1
# 371                      Finca Élez,Central Spain,Spain             1
# 218                  Colli Perugini,Central Italy,Italy             2
# 92     Blanquette de Limoux,Languedoc-Roussillon,France             1
# 378                     Fort Ross-Seaview,California,US             3
# 1023  Vin de Pays des Coteaux de Peyriac,Languedoc-R...             1
# 282               Coteaux du Lyonnais,Beaujolais,France             1
# 771                    Romangia,Sicily & Sardinia,Italy             3
# 113                                Bullas,Levante,Spain             2
# 51                  Australia,Australia Other,Australia            13
# 764   Riviera Ligure di Ponente,Northwestern Italy,I...             2
# ...                                                 ...           ...
# 82                     Beneventano,Southern Italy,Italy             2
# 655                  Niagara-On-The-Lake,Ontario,Canada             5
# 1056                               Virginia,Virginia,US            24
# 670                                        Ohio,Ohio,US             5
# 742                         Rasteau,Rhône Valley,France             1
# 593                     Moulin-à-Vent,Beaujolais,France             1
# 823                             San Lucas,California,US             2
# 691               Pemberton,Western Australia,Australia             6
# 298                      Côte Rôtie,Rhône Valley,France             2
# 259                 Corton Les Lolières,Burgundy,France             1
# 44               Arribes del Duero,Northern Spain,Spain             1
# 564   Montepulciano d'Abruzzo Cerasuolo,Central Ital...             1
# 139                            Carmignano,Tuscany,Italy             1
# 819                     San Francisco Bay,California,US             8
# 840                    Santa Clara Valley,California,US            17
# 618                        Mâcon-Fuissé,Burgundy,France             1
# 374                               Fixin,Burgundy,France             1
# 506                       Manchuela,Central Spain,Spain             2
# 231                 Colline Teatine,Central Italy,Italy             3
# 1082                        York Mountain,California,US             4
# 270                Coteaux Bourguignons,Burgundy,France             2
# 787                               Rully,Burgundy,France             2
# 793                    Río Negro Valley,Other,Argentina             4
# 620                    Mâcon-Pierreclos,Burgundy,France             1
# 759             Ribera del Queiles,Northern Spain,Spain             2
# 426                  Hilltops,New South Wales,Australia             1
# 31              Amarone della Valpolicella,Veneto,Italy             2
# 47                                  Asti,Piedmont,Italy             2
# 35    Anderson Valley-Sonoma County-Cole Ranch,Calif...             1
# 928                            Todi,Central Italy,Italy             1
#
# [1000 rows x 2 columns]

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
# Loop through the locations and run a lat/long search for each city
for idx, row in sample_num_varieties.iterrows():
#    print(idx)
    sample_target = row["Location"]
    # update address key value
    params['address'] = f"{sample_target}"
    # make request
    location_lat_lng = requests.get(base_url, params=params)
    # convert to json
    location_lat_lng = location_lat_lng.json()
    try:
        sample_num_varieties.loc[idx, "Lat"] = location_lat_lng["results"][0]["geometry"]["location"]["lat"]
        sample_num_varieties.loc[idx, "Lng"] = location_lat_lng["results"][0]["geometry"]["location"]["lng"]
    except(KeyError, IndexError):
        print("Missing field/result... skipping.")
        continue
# Visualize to confirm lat lng appear
sample_num_varieties = sample_num_varieties.dropna()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.

# %%
sample_num_varieties
# Out:
#                                                Location  Wine Variety  \
# 857                               Sebino,Lombardy,Italy             1
# 740                          Quincy,Loire Valley,France             1
# 640                           Napa-Sonoma,California,US             7
# 189                 Châteaumeillant,Loire Valley,France             3
# 338                              Dundee Hills,Oregon,US             8
# 98                       Bordeaux Blanc,Bordeaux,France             7
# 1074                    Yadkin Valley,North Carolina,US             3
# 63                Barbera del Monferrato,Piedmont,Italy             1
# 646                             Neuquén,Other,Argentina            10
# 1008    Vin de Pays de Caux,Languedoc-Roussillon,France             1
# 698                       Petit Chablis,Burgundy,France             1
# 683                        Paestum,Southern Italy,Italy             1
# 275                   Coteaux de Verdon,Provence,France             1
# 453              La Consulta,Mendoza Province,Argentina             3
# 203                 Clarendon,South Australia,Australia             5
# 880                         Sonoma Valley,California,US            38
# 1052   Vino de la Tierra de Zamora,Northern Spain,Spain             1
# 915               Terra degli Osci,Southern Italy,Italy             4
# 465                               Lake Erie,New York,US             1
# 76                         Beaujolais,Beaujolais,France             1
# 92     Blanquette de Limoux,Languedoc-Roussillon,France             1
# 378                     Fort Ross-Seaview,California,US             3
# 1023  Vin de Pays des Coteaux de Peyriac,Languedoc-R...             1
# 282               Coteaux du Lyonnais,Beaujolais,France             1
# 771                    Romangia,Sicily & Sardinia,Italy             3
# 113                                Bullas,Levante,Spain             2
# 51                  Australia,Australia Other,Australia            13
# 764   Riviera Ligure di Ponente,Northwestern Italy,I...             2
# 563               Montello e Colli Asolani,Veneto,Italy             2
# 812                      Salina,Sicily & Sardinia,Italy             2
# ...                                                 ...           ...
# 650                            New Mexico,New Mexico,US            11
# 82                     Beneventano,Southern Italy,Italy             2
# 655                  Niagara-On-The-Lake,Ontario,Canada             5
# 1056                               Virginia,Virginia,US            24
# 670                                        Ohio,Ohio,US             5
# 742                         Rasteau,Rhône Valley,France             1
# 593                     Moulin-à-Vent,Beaujolais,France             1
# 823                             San Lucas,California,US             2
# 691               Pemberton,Western Australia,Australia             6
# 298                      Côte Rôtie,Rhône Valley,France             2
# 259                 Corton Les Lolières,Burgundy,France             1
# 44               Arribes del Duero,Northern Spain,Spain             1
# 564   Montepulciano d'Abruzzo Cerasuolo,Central Ital...             1
# 139                            Carmignano,Tuscany,Italy             1
# 819                     San Francisco Bay,California,US             8
# 840                    Santa Clara Valley,California,US            17
# 618                        Mâcon-Fuissé,Burgundy,France             1
# 374                               Fixin,Burgundy,France             1
# 231                 Colline Teatine,Central Italy,Italy             3
# 1082                        York Mountain,California,US             4
# 270                Coteaux Bourguignons,Burgundy,France             2
# 787                               Rully,Burgundy,France             2
# 793                    Río Negro Valley,Other,Argentina             4
# 620                    Mâcon-Pierreclos,Burgundy,France             1
# 759             Ribera del Queiles,Northern Spain,Spain             2
# 426                  Hilltops,New South Wales,Australia             1
# 31              Amarone della Valpolicella,Veneto,Italy             2
# 47                                  Asti,Piedmont,Italy             2
# 35    Anderson Valley-Sonoma County-Cole Ranch,Calif...             1
# 928                            Todi,Central Italy,Italy             1
#
#             Lat         Lng
# 857   45.721871   10.067040
# 740   47.132235    2.156712
# 640   38.291859 -122.458036
# 189   46.562103    2.201875
# 338   45.279585 -123.009514
# 98    44.837789   -0.579180
# 1074  36.202360  -80.677079
# 63    44.817559    8.704663
# 646  -38.945870  -68.073093
# 1008  43.499387    3.338263
# 698   47.812123    3.802671
# 683   40.423151   15.007163
# 275   43.746498    6.098248
# 453  -33.733929  -69.119907
# 203  -35.105449  138.629743
# 880   38.291859 -122.458036
# 1052  41.609574   -5.898714
# 915   28.137658  -80.672994
# 465   42.624226  -79.066983
# 76    39.521896 -119.822207
# 92    43.068406    2.219818
# 378   38.514260 -123.243557
# 1023  43.291520    2.565892
# 282   45.764043    4.835659
# 771   37.599994   14.015356
# 113   38.043345   -1.673640
# 51   -25.274398  133.775136
# 764   43.194575    8.133856
# 563   45.781278   12.070338
# 812   40.120875    9.012893
# ...         ...         ...
# 650   34.519940 -105.870090
# 82    41.129761   14.782621
# 655   43.254999  -79.077262
# 1056  37.431573  -78.656894
# 670   40.417287  -82.907123
# 742   44.224843    4.988436
# 593   46.205148    4.724786
# 823   36.128855 -121.020467
# 691  -34.440000  116.050000
# 298   45.715529    4.440604
# 259   47.065692    4.859940
# 44    41.194726   -6.556988
# 564   42.192012   13.728917
# 139   43.800747   11.014619
# 819   37.827178 -122.291308
# 840   37.248848 -121.839959
# 618   46.280354    4.742589
# 374   47.245340    4.972309
# 231   28.137658  -80.672994
# 1082  35.369948 -115.161599
# 270   47.052505    4.383722
# 787   46.875041    4.740823
# 793  -40.826143  -63.026634
# 620   46.334809    4.686365
# 759   41.919693   -1.716695
# 426  -34.350000  150.483333
# 31    45.522139   10.907911
# 47    44.900751    8.206426
# 35    39.086566 -123.479454
# 928   42.781935   12.406569
#
# [963 rows x 4 columns]

# %%
num = sample_num_varieties["Wine Variety"].tolist()
# Create a map using state centroid coordinates to set markers
marker_locations = sample_num_varieties[['Lat', 'Lng']]
figure_layout = {
    'width': '1200px',
    'height': '1200px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)


# Create a marker_layer using the poverty list to fill the info box
heat_layer = gmaps.heatmap_layer(marker_locations, weights=num, 
                                 dissipating=True, max_intensity=10,
                                point_radius=3.5)


fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='1200px', margin='0 auto 0 auto', padding='1px', w…

# %%
# Dependencies
import pandas as pd
import numpy as np
import gmaps
import requests
from config import  gkey
import time
# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
wine_data = "winemag-data_first150k.csv"
wine_df = pd.read_csv(wine_data)
wine_df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
wine_df2=wine_df.drop(columns= ["Unnamed: 0","region_2"], axis=1)
wine_df2.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1             variety                   winery
# 0        Napa Valley  Cabernet Sauvignon                    Heitz
# 1               Toro       Tinta de Toro  Bodega Carmen Rodríguez
# 2     Knights Valley     Sauvignon Blanc                 Macauley
# 3  Willamette Valley          Pinot Noir                    Ponzi
# 4             Bandol  Provence red blend     Domaine de la Bégude

# %%
dropped_wine= wine_df2.dropna()
dropped_wine.count()
# Out:
# country        77284
# description    77284
# designation    77284
# points         77284
# price          77284
# province       77284
# region_1       77284
# variety        77284
# winery         77284
# dtype: int64

# %%
target_area = (dropped_wine["region_1"]+","+dropped_wine["province"]+","+dropped_wine["country"])
type(target_area)
# Out:
# pandas.core.series.Series

# %%
unique_variety = dropped_wine["variety"]
type(unique_variety)
# Out:
# pandas.core.series.Series

# %%
wv = pd.DataFrame({"Location": target_area,"Wine Variety": unique_variety})
wv_group = wv.groupby("Location")
num_varieties = pd.DataFrame(wv_group["Wine Variety"].nunique()).reset_index()
#just sampling for testing purposes
sample_num_varieties = num_varieties.sample(1000)
sample_num_varieties
# Out:
#                                                Location  Wine Variety
# 118          Cadillac Côtes de Bordeaux,Bordeaux,France             1
# 393                       Galatina,Southern Italy,Italy             1
# 177              Chianti Colli Fiorentini,Tuscany,Italy             2
# 829               San Rafael,Mendoza Province,Argentina             9
# 250                   Contra Costa County,California,US            12
# 747              Recioto di Soave Classico,Veneto,Italy             1
# 1023  Vin de Pays des Coteaux de Peyriac,Languedoc-R...             1
# 712                    Pouilly-Fumé,Loire Valley,France             2
# 175                        Cheverny,Loire Valley,France             1
# 626                               Médoc,Bordeaux,France             2
# 955       Valdobbiadene Prosecco Superiore,Veneto,Italy             1
# 899                   Stags Leap District,California,US             9
# 958              Valle d'Aosta,Northwestern Italy,Italy             1
# 211                  Colli Aprutini,Central Italy,Italy             5
# 858                             Seneca Lake,New York,US             9
# 1040           Vino Tierra de León,Northern Spain,Spain             3
# 567         Monteregio di Massa Marittima,Tuscany,Italy             2
# 424                       Hermitage,Rhône Valley,France             3
# 630             Napa County-Sonoma County,California,US             4
# 1035    Vin de Pays du Val de Loire,Loire Valley,France             3
# 178                  Chianti Colli Pisani,Tuscany,Italy             1
# 780                   Rosso di Montalcino,Tuscany,Italy             2
# 688                           Patagonia,Other,Argentina             9
# 314                Côtes du Lot,Southwest France,France             6
# 351                        Empordà,Northern Spain,Spain             4
# 1050  Vino de la Tierra de Castilla,Central Spain,Spain            24
# 545                              Middleburg,Virginia,US             2
# 280        Coteaux du Layon La Faye,Loire Valley,France             1
# 455                            La Rioja,Other,Argentina             2
# 446                               Jumilla,Levante,Spain             8
# ...                                                 ...           ...
# 417                          Hames Valley,California,US             1
# 535                        Mendocino-Lake,California,US             2
# 45                   Arroyo Grande Valley,California,US            15
# 1045  Vino de la Tierra Contraviesa Alpujarra,Andalu...             5
# 506                       Manchuela,Central Spain,Spain             2
# 1061                             Volnay,Burgundy,France             1
# 436                  Irrouléguy,Southwest France,France             1
# 1025  Vin de Pays des Côtes de Gascogne,Southwest Fr...            13
# 443                               Jerez,Andalucia,Spain             3
# 548                                Missouri,Missouri,US             7
# 488                      Livermore Valley,California,US            36
# 302              Côte de Nuits-Villages,Burgundy,France             1
# 413          Great Southern,Western Australia,Australia             5
# 616                    Mâcon-Chardonnay,Burgundy,France             1
# 129                       Campania,Southern Italy,Italy             9
# 1020  Vin de Pays des Coteaux de Bessilles,Languedoc...             1
# 895                    St. David's Bench,Ontario,Canada             2
# 404                        Gigondas,Rhône Valley,France             2
# 401            Getariako Txakolina,Northern Spain,Spain             3
# 695                 Perdriel,Mendoza Province,Argentina             4
# 510                          Marche,Central Italy,Italy            11
# 705                               Polk County,Oregon,US             1
# 286                      Crémant d'Alsace,Alsace,France             7
# 799           Saint-Chinian,Languedoc-Roussillon,France             3
# 36                   Anjou Villages,Loire Valley,France             2
# 72                      Basilicata,Southern Italy,Italy             5
# 856                          Savoie,France Other,France             1
# 74                   Beaujolais Blanc,Beaujolais,France             1
# 1083                  Yorkville Highlands,California,US            12
# 709                      Pompeiano,Southern Italy,Italy             5
#
# [1000 rows x 2 columns]

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
# Loop through the locations and run a lat/long search for each city
for idx, row in sample_num_varieties.iterrows():
#    print(idx)
    sample_target = row["Location"]
    # update address key value
    params['address'] = f"{sample_target}"
    # make request
    location_lat_lng = requests.get(base_url, params=params)
    # convert to json
    location_lat_lng = location_lat_lng.json()
    try:
        sample_num_varieties.loc[idx, "Lat"] = location_lat_lng["results"][0]["geometry"]["location"]["lat"]
        sample_num_varieties.loc[idx, "Lng"] = location_lat_lng["results"][0]["geometry"]["location"]["lng"]
    except(KeyError, IndexError):
        print("Missing field/result... skipping.")
        continue
# Visualize to confirm lat lng appear
sample_num_varieties = sample_num_varieties.dropna()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.

# %%
sample_num_varieties
# Out:
#                                                Location  Wine Variety  \
# 118          Cadillac Côtes de Bordeaux,Bordeaux,France             1
# 393                       Galatina,Southern Italy,Italy             1
# 177              Chianti Colli Fiorentini,Tuscany,Italy             2
# 829               San Rafael,Mendoza Province,Argentina             9
# 250                   Contra Costa County,California,US            12
# 747              Recioto di Soave Classico,Veneto,Italy             1
# 1023  Vin de Pays des Coteaux de Peyriac,Languedoc-R...             1
# 712                    Pouilly-Fumé,Loire Valley,France             2
# 175                        Cheverny,Loire Valley,France             1
# 626                               Médoc,Bordeaux,France             2
# 955       Valdobbiadene Prosecco Superiore,Veneto,Italy             1
# 899                   Stags Leap District,California,US             9
# 958              Valle d'Aosta,Northwestern Italy,Italy             1
# 211                  Colli Aprutini,Central Italy,Italy             5
# 858                             Seneca Lake,New York,US             9
# 567         Monteregio di Massa Marittima,Tuscany,Italy             2
# 424                       Hermitage,Rhône Valley,France             3
# 630             Napa County-Sonoma County,California,US             4
# 1035    Vin de Pays du Val de Loire,Loire Valley,France             3
# 178                  Chianti Colli Pisani,Tuscany,Italy             1
# 780                   Rosso di Montalcino,Tuscany,Italy             2
# 688                           Patagonia,Other,Argentina             9
# 314                Côtes du Lot,Southwest France,France             6
# 351                        Empordà,Northern Spain,Spain             4
# 1050  Vino de la Tierra de Castilla,Central Spain,Spain            24
# 545                              Middleburg,Virginia,US             2
# 280        Coteaux du Layon La Faye,Loire Valley,France             1
# 455                            La Rioja,Other,Argentina             2
# 446                               Jumilla,Levante,Spain             8
# 720          Primitivo di Manduria,Southern Italy,Italy             1
# ...                                                 ...           ...
# 83                         Bennett Valley,California,US             9
# 155                 Central Victoria,Victoria,Australia             1
# 146    Catalanesca del Monte Somma,Southern Italy,Italy             1
# 232                Colline Teramane,Central Italy,Italy             1
# 417                          Hames Valley,California,US             1
# 535                        Mendocino-Lake,California,US             2
# 45                   Arroyo Grande Valley,California,US            15
# 1045  Vino de la Tierra Contraviesa Alpujarra,Andalu...             5
# 1061                             Volnay,Burgundy,France             1
# 443                               Jerez,Andalucia,Spain             3
# 548                                Missouri,Missouri,US             7
# 302              Côte de Nuits-Villages,Burgundy,France             1
# 413          Great Southern,Western Australia,Australia             5
# 616                    Mâcon-Chardonnay,Burgundy,France             1
# 129                       Campania,Southern Italy,Italy             9
# 1020  Vin de Pays des Coteaux de Bessilles,Languedoc...             1
# 895                    St. David's Bench,Ontario,Canada             2
# 404                        Gigondas,Rhône Valley,France             2
# 401            Getariako Txakolina,Northern Spain,Spain             3
# 695                 Perdriel,Mendoza Province,Argentina             4
# 510                          Marche,Central Italy,Italy            11
# 705                               Polk County,Oregon,US             1
# 286                      Crémant d'Alsace,Alsace,France             7
# 799           Saint-Chinian,Languedoc-Roussillon,France             3
# 36                   Anjou Villages,Loire Valley,France             2
# 72                      Basilicata,Southern Italy,Italy             5
# 856                          Savoie,France Other,France             1
# 74                   Beaujolais Blanc,Beaujolais,France             1
# 1083                  Yorkville Highlands,California,US            12
# 709                      Pompeiano,Southern Italy,Italy             5
#
#             Lat         Lng
# 118   44.837117   -0.571500
# 393   40.175823   18.172476
# 177   43.625365   11.121063
# 829  -34.612892  -68.339062
# 250   37.853409 -121.901795
# 747   45.421108   11.249017
# 1023  43.291520    2.565892
# 712   47.297296    2.958654
# 175   47.499730    1.460130
# 626   44.839505   -0.586951
# 955   45.877286   12.034054
# 899   38.414183 -122.321313
# 958   45.738888    7.426187
# 211   42.338516   14.059119
# 858   42.691850  -76.920192
# 567   43.049272   10.887409
# 424   45.640290    5.686499
# 630   38.291859 -122.458036
# 1035  47.482995   -0.541810
# 178   43.771051   11.248621
# 780   42.967171   11.437808
# 688  -41.810147  -68.906269
# 314   44.537936    1.676069
# 351   42.275527    3.017571
# 1050  39.008509   -3.363121
# 545   38.968721  -77.735550
# 280   47.302297   -0.550947
# 455  -29.419379  -66.855993
# 446   38.474086   -1.325355
# 720   40.405829   17.636336
# ...         ...         ...
# 83    38.402361 -122.640481
# 155  -37.471308  144.785153
# 146   40.833333   14.433333
# 232   28.137658  -80.672994
# 417   35.874411 -120.834623
# 535   39.217384 -123.171699
# 45    35.144336 -120.543623
# 1045  36.880581   -3.185691
# 1061  47.001510    4.781618
# 443   36.685006   -6.126074
# 548   37.964253  -91.831833
# 302   47.137985    4.950320
# 413  -31.944542  115.863715
# 616   46.480588    4.815828
# 129   41.109947   14.847514
# 1020  43.407331    3.565707
# 895   43.160324  -79.104043
# 404   44.163231    5.004180
# 401   43.307734   -2.202149
# 695  -33.076429  -68.886894
# 510   43.505874   12.989615
# 705   44.926653 -123.491926
# 286   48.022443    7.284551
# 799   43.418646    2.945129
# 36    47.553240    1.010529
# 72    40.643077   15.969988
# 856   45.390221    6.862928
# 74    45.987484    4.721040
# 1083  38.897959 -123.214451
# 709   28.137658  -80.672994
#
# [965 rows x 4 columns]

# %%
num = sample_num_varieties["Wine Variety"].tolist()
# Create a map using state centroid coordinates to set markers
marker_locations = sample_num_varieties[['Lat', 'Lng']]
figure_layout = {
    'width': '1200px',
    'height': '1200px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)


# Create a marker_layer using the poverty list to fill the info box
heat_layer = gmaps.heatmap_layer(marker_locations, weights=num, 
                                 dissipating=True, max_intensity=10,
                                point_radius=3.5)


fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='1200px', margin='0 auto 0 auto', padding='1px', w…
